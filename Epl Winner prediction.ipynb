# %% [markdown]
# **Portfolio Project: Predicting EPL Football Match Winners With Machine Learning**

# %%
# Reading in the initial data

import pandas as pd

matches = pd.read_csv("matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (1389, 27)

# %%
matches["team"].value_counts()
# Out:
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: team, dtype: int64

# %%
matches['round'].value_counts()
# Out:
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: round, dtype: int64

# %% [markdown]
# **CLEANING DATA FOR MACHINE LEARNING**

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches['date'] = pd.to_datetime(matches['date'])
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %% [markdown]
# **CREATING PREDICTORS FOR MACHINE LEARNING**

# %%
matches['venue_code'] = matches["venue"].astype('category').cat.codes
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# 1   1.0       Tottenham  ...    NaN  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2   0.0    Norwich City  ...    NaN  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3   0.0         Arsenal  ...    NaN  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4   0.0  Leicester City  ...    NaN  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6   0.0     Southampton  ...    NaN  16.0   1.0  15.7  1.0  0.0   0.0   2022
# ..  ...             ...  ...    ...   ...   ...   ...  ...  ...   ...    ...
# 38  4.0       Tottenham  ...    NaN   8.0   1.0  17.4  0.0  0.0   0.0   2021
# 39  2.0  Crystal Palace  ...    NaN   7.0   0.0  11.4  1.0  0.0   0.0   2021
# 40  0.0         Everton  ...    NaN  10.0   3.0  17.0  0.0  0.0   0.0   2021
# 41  1.0   Newcastle Utd  ...    NaN  11.0   1.0  16.0  1.0  0.0   0.0   2021
# 42  0.0         Burnley  ...    NaN  12.0   3.0  17.0  0.0  0.0   0.0   2021
#
#                 team  venue_code
# 1    Manchester City           0
# 2    Manchester City           1
# 3    Manchester City           1
# 4    Manchester City           0
# 6    Manchester City           1
# ..               ...         ...
# 38  Sheffield United           0
# 39  Sheffield United           1
# 40  Sheffield United           0
# 41  Sheffield United           0
# 42  Sheffield United           1
#
# [1389 rows x 28 columns]

# %%
matches['venue_code'] = matches["venue"].astype('category').cat.codes
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# 1   1.0       Tottenham  ...    NaN  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2   0.0    Norwich City  ...    NaN  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3   0.0         Arsenal  ...    NaN  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4   0.0  Leicester City  ...    NaN  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6   0.0     Southampton  ...    NaN  16.0   1.0  15.7  1.0  0.0   0.0   2022
# ..  ...             ...  ...    ...   ...   ...   ...  ...  ...   ...    ...
# 38  4.0       Tottenham  ...    NaN   8.0   1.0  17.4  0.0  0.0   0.0   2021
# 39  2.0  Crystal Palace  ...    NaN   7.0   0.0  11.4  1.0  0.0   0.0   2021
# 40  0.0         Everton  ...    NaN  10.0   3.0  17.0  0.0  0.0   0.0   2021
# 41  1.0   Newcastle Utd  ...    NaN  11.0   1.0  16.0  1.0  0.0   0.0   2021
# 42  0.0         Burnley  ...    NaN  12.0   3.0  17.0  0.0  0.0   0.0   2021
#
#                 team  venue_code
# 1    Manchester City           0
# 2    Manchester City           1
# 3    Manchester City           1
# 4    Manchester City           0
# 6    Manchester City           1
# ..               ...         ...
# 38  Sheffield United           0
# 39  Sheffield United           1
# 40  Sheffield United           0
# 41  Sheffield United           0
# 42  Sheffield United           1
#
# [1389 rows x 28 columns]

# %%
matches['opp_code'] = matches['opponent'].astype('category').cat.codes

# %%
matches['hour'] = matches['time'].str.replace(":.+", "", regex=True).astype("int")

# %%
matches['day_code'] = matches["date"].dt.dayofweek
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  dist   fk   pk  pkatt season              team  \
# 1   1.0       Tottenham  ...  16.9  1.0  0.0    0.0   2022   Manchester City
# 2   0.0    Norwich City  ...  17.3  1.0  0.0    0.0   2022   Manchester City
# 3   0.0         Arsenal  ...  14.3  0.0  0.0    0.0   2022   Manchester City
# 4   0.0  Leicester City  ...  14.0  0.0  0.0    0.0   2022   Manchester City
# 6   0.0     Southampton  ...  15.7  1.0  0.0    0.0   2022   Manchester City
# ..  ...             ...  ...   ...  ...  ...    ...    ...               ...
# 38  4.0       Tottenham  ...  17.4  0.0  0.0    0.0   2021  Sheffield United
# 39  2.0  Crystal Palace  ...  11.4  1.0  0.0    0.0   2021  Sheffield United
# 40  0.0         Everton  ...  17.0  0.0  0.0    0.0   2021  Sheffield United
# 41  1.0   Newcastle Utd  ...  16.0  1.0  0.0    0.0   2021  Sheffield United
# 42  0.0         Burnley  ...  17.0  0.0  0.0    0.0   2021  Sheffield United
#
#    venue_code opp_code  hour  day_code
# 1           0       18    16         6
# 2           1       15    15         5
# 3           1        0    12         5
# 4           0       10    15         5
# 6           1       17    15         5
# ..        ...      ...   ...       ...
# 38          0       18    19         6
# 39          1        6    15         5
# 40          0        7    19         6
# 41          0       14    18         2
# 42          1        4    16         6
#
# [1389 rows x 31 columns]

# %%
matches["target"] = (matches['result'] == 'W').astype('int')
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...   fk   pk  pkatt  season              team  \
# 1   1.0       Tottenham  ...  1.0  0.0    0.0    2022   Manchester City
# 2   0.0    Norwich City  ...  1.0  0.0    0.0    2022   Manchester City
# 3   0.0         Arsenal  ...  0.0  0.0    0.0    2022   Manchester City
# 4   0.0  Leicester City  ...  0.0  0.0    0.0    2022   Manchester City
# 6   0.0     Southampton  ...  1.0  0.0    0.0    2022   Manchester City
# ..  ...             ...  ...  ...  ...    ...     ...               ...
# 38  4.0       Tottenham  ...  0.0  0.0    0.0    2021  Sheffield United
# 39  2.0  Crystal Palace  ...  1.0  0.0    0.0    2021  Sheffield United
# 40  0.0         Everton  ...  0.0  0.0    0.0    2021  Sheffield United
# 41  1.0   Newcastle Utd  ...  1.0  0.0    0.0    2021  Sheffield United
# 42  0.0         Burnley  ...  0.0  0.0    0.0    2021  Sheffield United
#
#    venue_code opp_code hour  day_code  target
# 1           0       18   16         6       0
# 2           1       15   15         5       1
# 3           1        0   12         5       1
# 4           0       10   15         5       1
# 6           1       17   15         5       0
# ..        ...      ...  ...       ...     ...
# 38          0       18   19         6       0
# 39          1        6   15         5       0
# 40          0        7   19         6       1
# 41          0       14   18         2       0
# 42          1        4   16         6       1
#
# [1389 rows x 32 columns]

# %% [markdown]
# **TRAINING AN INITIAL ML MODEL**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF = RandomForestClassifier(n_estimators=58, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches['date'] > '2022-01-01']

# %%
predictors = ['venue_code', 'opp_code', 'hour', 'day_code']

# %%
RF.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=58, random_state=1)

# %%
preds = RF.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test['target'], preds)

# %%
acc
# Out:
# 0.605072463768116

# %%
combined = pd.DataFrame(dict(actual=test['target'], prediction= preds))

# %%
pd.crosstab(index = combined['actual'], columns= combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           138  34
# 1            75  29

# %%
from sklearn.metrics import precision_score
precision_score (test['target'], preds)
# Out:
# 0.4603174603174603

# %% [markdown]
# **Improving the Model with Rolling Averages**

# %%
segmented_matches = matches.groupby("team")

# %%
group = segmented_matches.get_group("Arsenal")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 0  2021-08-13  20:00  Premier League   Matchweek 1  Fri  Away      L  0.0
# 1  2021-08-22  16:30  Premier League   Matchweek 2  Sun  Home      L  0.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Away      L  0.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 52 2021-05-02  14:00  Premier League  Matchweek 34  Sun  Away      W  2.0
# 54 2021-05-09  19:00  Premier League  Matchweek 35  Sun  Home      W  3.0
# 55 2021-05-12  20:15  Premier League  Matchweek 36  Wed  Away      W  1.0
# 56 2021-05-19  19:00  Premier League  Matchweek 37  Wed  Away      W  3.0
# 57 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
#
#      ga         opponent  ...   fk   pk  pkatt  season     team venue_code  \
# 0   2.0        Brentford  ...  1.0  0.0    0.0    2022  Arsenal          0
# 1   2.0          Chelsea  ...  0.0  0.0    0.0    2022  Arsenal          1
# 3   5.0  Manchester City  ...  0.0  0.0    0.0    2022  Arsenal          0
# 4   0.0     Norwich City  ...  1.0  0.0    0.0    2022  Arsenal          1
# 5   0.0          Burnley  ...  1.0  0.0    0.0    2022  Arsenal          0
# ..  ...              ...  ...  ...  ...    ...     ...      ...        ...
# 52  0.0    Newcastle Utd  ...  1.0  0.0    0.0    2021  Arsenal          0
# 54  1.0        West Brom  ...  1.0  0.0    0.0    2021  Arsenal          1
# 55  0.0          Chelsea  ...  0.0  0.0    0.0    2021  Arsenal          0
# 56  1.0   Crystal Palace  ...  0.0  0.0    0.0    2021  Arsenal          0
# 57  0.0         Brighton  ...  1.0  0.0    0.0    2021  Arsenal          1
#
#    opp_code hour  day_code  target
# 0         2   20         4       0
# 1         5   16         6       0
# 3        12   12         5       0
# 4        15   15         5       1
# 5         4   15         5       1
# ..      ...  ...       ...     ...
# 52       14   14         6       1
# 54       20   19         6       1
# 55        5   20         2       1
# 56        6   19         2       1
# 57        3   16         6       1
#
# [71 rows x 32 columns]

# %%
def rolling_averages(group, cols, new_cols):
    rolling_stats = group[cols].rolling(3, closed ="left").mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset= new_cols)
    return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk','pk', 'pkatt']
new_cols=[f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
# C:\Users\ALEX\anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 52 2021-05-02  14:00  Premier League  Matchweek 34  Sun  Away      W  2.0
# 54 2021-05-09  19:00  Premier League  Matchweek 35  Sun  Home      W  3.0
# 55 2021-05-12  20:15  Premier League  Matchweek 36  Wed  Away      W  1.0
# 56 2021-05-19  19:00  Premier League  Matchweek 37  Wed  Away      W  3.0
# 57 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  2.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 4   0.0    Norwich City  ...         5       1    0.000000    3.000000
# 5   0.0         Burnley  ...         5       1    0.333333    2.333333
# 7   1.0       Tottenham  ...         6       1    0.666667    1.666667
# 8   0.0        Brighton  ...         5       0    1.666667    0.333333
# 9   2.0  Crystal Palace  ...         0       0    1.333333    0.333333
# ..  ...             ...  ...       ...     ...         ...         ...
# 52  0.0   Newcastle Utd  ...         6       1    1.333333    0.666667
# 54  1.0       West Brom  ...         6       1    1.000000    0.666667
# 55  0.0         Chelsea  ...         2       1    1.666667    0.666667
# 56  1.0  Crystal Palace  ...         2       1    2.000000    0.333333
# 57  0.0        Brighton  ...         6       1    2.333333    0.666667
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4    9.666667    2.333333    14.600000   0.333333         0.0            0.0
# 5   12.333333    3.000000    13.866667   0.333333         0.0            0.0
# 7   14.666667    3.000000    14.766667   0.666667         0.0            0.0
# 8   18.333333    5.333333    18.000000   0.666667         0.0            0.0
# 9   11.000000    4.000000    18.966667   0.666667         0.0            0.0
# ..        ...         ...          ...        ...         ...            ...
# 52  15.333333    4.333333    16.833333   0.666667         0.0            0.0
# 54  17.000000    4.000000    16.000000   0.666667         0.0            0.0
# 55  16.000000    4.666667    17.100000   0.666667         0.0            0.0
# 56  13.000000    4.333333    17.933333   0.666667         0.0            0.0
# 57   8.666667    4.000000    17.333333   0.333333         0.0            0.0
#
# [68 rows x 40 columns]

# %%
matches_rolling = matches.groupby('team').apply(lambda x: rolling_averages (x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2021-09-11  15:00  Premier League   Matchweek 4
#                         5  2021-09-18  15:00  Premier League   Matchweek 5
#                         7  2021-09-26  16:30  Premier League   Matchweek 6
#                         8  2021-10-02  17:30  Premier League   Matchweek 7
#                         9  2021-10-18  20:00  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 37 2021-05-03  18:00  Premier League  Matchweek 34
#                         38 2021-05-09  12:00  Premier League  Matchweek 35
#                         39 2021-05-16  14:05  Premier League  Matchweek 36
#                         40 2021-05-19  18:00  Premier League  Matchweek 37
#                         41 2021-05-23  16:00  Premier League  Matchweek 38
#
#                             day venue result   gf   ga        opponent  ...  \
# team                                                                    ...
# Arsenal                 4   Sat  Home      W  1.0  0.0    Norwich City  ...
#                         5   Sat  Away      W  1.0  0.0         Burnley  ...
#                         7   Sun  Home      W  3.0  1.0       Tottenham  ...
#                         8   Sat  Away      D  0.0  0.0        Brighton  ...
#                         9   Mon  Home      D  2.0  2.0  Crystal Palace  ...
# ...                         ...   ...    ...  ...  ...             ...  ...
# Wolverhampton Wanderers 37  Mon  Away      D  1.0  1.0       West Brom  ...
#                         38  Sun  Home      W  2.0  1.0        Brighton  ...
#                         39  Sun  Away      L  0.0  2.0       Tottenham  ...
#                         40  Wed  Away      L  0.0  1.0         Everton  ...
#                         41  Sun  Home      L  1.0  2.0  Manchester Utd  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4          5       1    0.000000    3.000000
#                         5          5       1    0.333333    2.333333
#                         7          6       1    0.666667    1.666667
#                         8          5       0    1.666667    0.333333
#                         9          0       0    1.333333    0.333333
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 37         0       0    0.666667    1.333333
#                         38         6       1    0.666667    1.666667
#                         39         6       0    1.000000    2.000000
#                         40         2       0    1.000000    1.333333
#                         41         6       0    0.666667    1.333333
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4    9.666667    2.333333    14.600000   0.333333
#                         5   12.333333    3.000000    13.866667   0.333333
#                         7   14.666667    3.000000    14.766667   0.666667
#                         8   18.333333    5.333333    18.000000   0.666667
#                         9   11.000000    4.000000    18.966667   0.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 37   9.666667    3.000000    17.266667   0.666667
#                         38  14.000000    5.333333    18.433333   0.333333
#                         39  15.666667    6.000000    20.000000   0.666667
#                         40  16.666667    6.333333    18.233333   0.333333
#                         41  13.000000    4.000000    18.700000   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 4          0.0            0.0
#                         5          0.0            0.0
#                         7          0.0            0.0
#                         8          0.0            0.0
#                         9          0.0            0.0
# ...                                ...            ...
# Wolverhampton Wanderers 37         0.0            0.0
#                         38         0.0            0.0
#                         39         0.0            0.0
#                         40         0.0            0.0
#                         41         0.0            0.0
#
# [1317 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 5  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 7  2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 8  2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 9  2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 37 2021-05-03  18:00  Premier League  Matchweek 34  Mon  Away      D  1.0
# 38 2021-05-09  12:00  Premier League  Matchweek 35  Sun  Home      W  2.0
# 39 2021-05-16  14:05  Premier League  Matchweek 36  Sun  Away      L  0.0
# 40 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 41 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      L  1.0
#
#      ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 4   0.0    Norwich City  ...         5       1    0.000000    3.000000
# 5   0.0         Burnley  ...         5       1    0.333333    2.333333
# 7   1.0       Tottenham  ...         6       1    0.666667    1.666667
# 8   0.0        Brighton  ...         5       0    1.666667    0.333333
# 9   2.0  Crystal Palace  ...         0       0    1.333333    0.333333
# ..  ...             ...  ...       ...     ...         ...         ...
# 37  1.0       West Brom  ...         0       0    0.666667    1.333333
# 38  1.0        Brighton  ...         6       1    0.666667    1.666667
# 39  2.0       Tottenham  ...         6       0    1.000000    2.000000
# 40  1.0         Everton  ...         2       0    1.000000    1.333333
# 41  2.0  Manchester Utd  ...         6       0    0.666667    1.333333
#
#    sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4    9.666667    2.333333    14.600000   0.333333         0.0            0.0
# 5   12.333333    3.000000    13.866667   0.333333         0.0            0.0
# 7   14.666667    3.000000    14.766667   0.666667         0.0            0.0
# 8   18.333333    5.333333    18.000000   0.666667         0.0            0.0
# 9   11.000000    4.000000    18.966667   0.666667         0.0            0.0
# ..        ...         ...          ...        ...         ...            ...
# 37   9.666667    3.000000    17.266667   0.666667         0.0            0.0
# 38  14.000000    5.333333    18.433333   0.333333         0.0            0.0
# 39  15.666667    6.000000    20.000000   0.666667         0.0            0.0
# 40  16.666667    6.333333    18.233333   0.333333         0.0            0.0
# 41  13.000000    4.000000    18.700000   0.333333         0.0            0.0
#
# [1317 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W  1.0
# 1    2021-09-18  15:00  Premier League   Matchweek 5  Sat  Away      W  1.0
# 2    2021-09-26  16:30  Premier League   Matchweek 6  Sun  Home      W  3.0
# 3    2021-10-02  17:30  Premier League   Matchweek 7  Sat  Away      D  0.0
# 4    2021-10-18  20:00  Premier League   Matchweek 8  Mon  Home      D  2.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2021-05-03  18:00  Premier League  Matchweek 34  Mon  Away      D  1.0
# 1313 2021-05-09  12:00  Premier League  Matchweek 35  Sun  Home      W  2.0
# 1314 2021-05-16  14:05  Premier League  Matchweek 36  Sun  Away      L  0.0
# 1315 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 1316 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      L  1.0
#
#        ga        opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0     0.0    Norwich City  ...         5       1    0.000000    3.000000
# 1     0.0         Burnley  ...         5       1    0.333333    2.333333
# 2     1.0       Tottenham  ...         6       1    0.666667    1.666667
# 3     0.0        Brighton  ...         5       0    1.666667    0.333333
# 4     2.0  Crystal Palace  ...         0       0    1.333333    0.333333
# ...   ...             ...  ...       ...     ...         ...         ...
# 1312  1.0       West Brom  ...         0       0    0.666667    1.333333
# 1313  1.0        Brighton  ...         6       1    0.666667    1.666667
# 1314  2.0       Tottenham  ...         6       0    1.000000    2.000000
# 1315  1.0         Everton  ...         2       0    1.000000    1.333333
# 1316  2.0  Manchester Utd  ...         6       0    0.666667    1.333333
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0      9.666667    2.333333    14.600000   0.333333         0.0            0.0
# 1     12.333333    3.000000    13.866667   0.333333         0.0            0.0
# 2     14.666667    3.000000    14.766667   0.666667         0.0            0.0
# 3     18.333333    5.333333    18.000000   0.666667         0.0            0.0
# 4     11.000000    4.000000    18.966667   0.666667         0.0            0.0
# ...         ...         ...          ...        ...         ...            ...
# 1312   9.666667    3.000000    17.266667   0.666667         0.0            0.0
# 1313  14.000000    5.333333    18.433333   0.333333         0.0            0.0
# 1314  15.666667    6.000000    20.000000   0.666667         0.0            0.0
# 1315  16.666667    6.333333    18.233333   0.333333         0.0            0.0
# 1316  13.000000    4.000000    18.700000   0.333333         0.0            0.0
#
# [1317 rows x 40 columns]

# %% [markdown]
# **Retraining Our Machine Learning Model**

# %%
def make_predictions(data, predictors):
    train = data[data['date']< '2022-01-01']
    test = data[data['date']> '2020-01-01']
    RF.fit(train[predictors], train['target'])
    preds= RF.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test ['target'], predicted = preds), index= test.index)
    precision = precision_score(test['target'], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)
precision
# Out:
# 0.9291338582677166

# %%
combined
# Out:
#       actual  predicted
# 0          1          1
# 1          1          1
# 2          1          1
# 3          0          0
# 4          0          0
# ...      ...        ...
# 1312       0          0
# 1313       1          1
# 1314       0          0
# 1315       0          0
# 1316       0          0
#
# [1317 rows x 2 columns]

# %%
combined = combined.merge (matches_rolling[['date', 'team', 'opponent', 'result',]], left_index = True, right_index = True)
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 0          1          1 2021-09-11                  Arsenal    Norwich City
# 1          1          1 2021-09-18                  Arsenal         Burnley
# 2          1          1 2021-09-26                  Arsenal       Tottenham
# 3          0          0 2021-10-02                  Arsenal        Brighton
# 4          0          0 2021-10-18                  Arsenal  Crystal Palace
# ...      ...        ...        ...                      ...             ...
# 1312       0          0 2021-05-03  Wolverhampton Wanderers       West Brom
# 1313       1          1 2021-05-09  Wolverhampton Wanderers        Brighton
# 1314       0          0 2021-05-16  Wolverhampton Wanderers       Tottenham
# 1315       0          0 2021-05-19  Wolverhampton Wanderers         Everton
# 1316       0          0 2021-05-23  Wolverhampton Wanderers  Manchester Utd
#
#      result
# 0         W
# 1         W
# 2         W
# 3         D
# 4         D
# ...     ...
# 1312      D
# 1313      W
# 1314      L
# 1315      L
# 1316      L
#
# [1317 rows x 6 columns]

# %% [markdown]
# **Combining Home And Away predictions**

# %%
class MissingDict(dict):
    _missing_ = lambda self, key: key
    
map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "Westham United": "WestHam",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
combined['new_team'] = combined['team'].map(mapping)
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 0          1          1 2021-09-11                  Arsenal    Norwich City
# 1          1          1 2021-09-18                  Arsenal         Burnley
# 2          1          1 2021-09-26                  Arsenal       Tottenham
# 3          0          0 2021-10-02                  Arsenal        Brighton
# 4          0          0 2021-10-18                  Arsenal  Crystal Palace
# ...      ...        ...        ...                      ...             ...
# 1312       0          0 2021-05-03  Wolverhampton Wanderers       West Brom
# 1313       1          1 2021-05-09  Wolverhampton Wanderers        Brighton
# 1314       0          0 2021-05-16  Wolverhampton Wanderers       Tottenham
# 1315       0          0 2021-05-19  Wolverhampton Wanderers         Everton
# 1316       0          0 2021-05-23  Wolverhampton Wanderers  Manchester Utd
#
#      result new_team
# 0         W      NaN
# 1         W      NaN
# 2         W      NaN
# 3         D      NaN
# 4         D      NaN
# ...     ...      ...
# 1312      D   Wolves
# 1313      W   Wolves
# 1314      L   Wolves
# 1315      L   Wolves
# 1316      L   Wolves
#
# [1317 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on = ['date', 'new_team'], right_on= ['date', 'opponent'])
merged
# Out:
#      actual_x  predicted_x       date                    team_x  \
# 0           1            1 2021-09-11  Brighton and Hove Albion
# 1           1            0 2021-09-19  Brighton and Hove Albion
# 2           0            0 2021-09-27  Brighton and Hove Albion
# 3           0            0 2021-10-02  Brighton and Hove Albion
# 4           0            0 2021-10-16  Brighton and Hove Albion
# ..        ...          ...        ...                       ...
# 329         0            0 2021-05-03   Wolverhampton Wanderers
# 330         1            1 2021-05-09   Wolverhampton Wanderers
# 331         0            0 2021-05-16   Wolverhampton Wanderers
# 332         0            0 2021-05-19   Wolverhampton Wanderers
# 333         0            0 2021-05-23   Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0         Brentford        W   Brighton         0            0
# 1    Leicester City        W   Brighton         0            0
# 2    Crystal Palace        D   Brighton         0            0
# 3           Arsenal        D   Brighton         0            0
# 4      Norwich City        D   Brighton         0            0
# ..              ...      ...        ...       ...          ...
# 329       West Brom        D     Wolves         0            0
# 330        Brighton        W     Wolves         0            0
# 331       Tottenham        L     Wolves         1            1
# 332         Everton        L     Wolves         1            1
# 333  Manchester Utd        L     Wolves         1            0
#
#                        team_y opponent_y result_y      new_team_y
# 0                   Brentford   Brighton        L             NaN
# 1              Leicester City   Brighton        L             NaN
# 2              Crystal Palace   Brighton        D             NaN
# 3                     Arsenal   Brighton        D             NaN
# 4                Norwich City   Brighton        D             NaN
# ..                        ...        ...      ...             ...
# 329      West Bromwich Albion     Wolves        D             NaN
# 330  Brighton and Hove Albion     Wolves        L        Brighton
# 331         Tottenham Hotspur     Wolves        W       Tottenham
# 332                   Everton     Wolves        W             NaN
# 333         Manchester United     Wolves        W  Manchester Utd
#
# [334 rows x 13 columns]

# %%
merged[(merged['predicted_x']==1) & (merged['predicted_y']==0)]['actual_x'].value_counts()
# Out:
# 1    87
# 0     8
# Name: actual_x, dtype: int64

# %%
87/40
# Out:
# 2.175
